# %% [markdown]
# # Classification and Captioning Aircraft Damage Using Pretrained Models

# %% [markdown]
# ## **Introduction**
#
# In this project, we will classify aircraft damage using a pre-trained VGG16 model and generate captions using a Transformer-based pretrained model.
#
# ## **Project Overview**
#
# Aircraft damage detection is essential for maintaining the safety and longevity of aircraft. Traditional manual inspection methods are time-consuming and prone to human error. This project aims to automate the classification of aircraft damage into two categories: "dent" and "crack." For this, we will utilize feature extraction with a pre-trained VGG16 model to classify the damage from aircraft images. Additionally, we will use a pre-trained Transformer model to generate captions and summaries for the images.
#
# ## **Aim of the Project**
#
# The goal of this project is to develop an automated model that accurately classifies aircraft damage from images. By the end of the project, you will have trained and evaluated a model that utilizes feature extraction from VGG16 for damage classification. This model will be applicable in real-world damage detection within the aviation industry. Furthermore, the project will showcase how we can use a Transformer-based model to caption and summarize images, providing a detailed description of the damage.
#
# ## **Final Output**
#
# - A trained model capable of classifying aircraft images into "dent" and "crack" categories, enabling automated aircraft damage detection.

# %% [markdown]
# We will be using the [Aircraft dataset](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/ZjXM4RKxlBK9__ZjHBLl5A/aircraft-damage-dataset-v1.tar).
# The dataset is taken from the here (Original Source): [Roboflow Aircraft Dataset](https://universe.roboflow.com/youssef-donia-fhktl/aircraft-damage-detection-1j9qk) Provided by a Roboflow user, License: CC BY 4.

# %% [markdown]
# <h2>Table of Contents</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <p><font size="5">Part 1 - Classification Problem: Classifying the defect on the aircraft as 'dent' or 'crack'</p>
# <font size="3">
#         1. <a href="#1.1-Dataset-Preparation">1.1 Dataset Preparation</a><br>
#         2. <a href="#1.2-Data-Preprocessing">1.2 Data Preprocessing</a><br>
#         3. <a href="#1.3-Model-Definition">1.3 Model Definition</a><br>
#         4. <a href="#1.4-Model-Training">1.4 Model Training</a><br>
#         5. <a href="#1.5-Visualizing-Training-Results">1.5 Visualizing Training Results</a><br>
#         6. <a href="#1.6-Model-Evaluation">1.6 Model Evaluation</a><br>
#         7. <a href="#1.7-Visualizing-Predictions">1.7 Visualizing Predictions</a><br>
#     <br>
# <p><font size="5">Part 2: Image Captioning and Summarization using BLIP Pretrained Model</p>
# <font size="3">
#         1. <a href="#2.1-Loading-BLIP-Model">2.1 Loading BLIP Model</a><br>
#         2. <a href="#2.2-Generating-Captions-and-Summaries">2.2 Generating Captions and Summaries</a><br>
#         <br>

# %% [markdown]
# # 1.1 Dataset-Preparation

# %% [markdown]
#  ### Task List
# To achieve the above objectives, we will complete the following tasks:
#
# - Task 1: Create a `valid_generator` using the `valid_datagen` object
# - Task 2: Create a `test_generator` using the `test_datagen` object
# - Task 3: Load the VGG16 model
# - Task 4: Compile the model
# - Task 5: Train the model
# - Task 6: Plot accuracy curves for training and validation sets
# - Task 7: Visualizing the results
# - Task 8: Implement a Helper Function to Use the Custom Keras Layer
# - Task 9: Generate a caption for an image using the using BLIP pretrained model
# - Task 10: Generate a summary of an image using BLIP pretrained model

# %% [markdown]
# ## Setup

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Installing Required Libraries

# %%
# !pip install pandas==2.2.3
# !pip install tensorflow==2.17.1
# !pip install pillow==11.1.0
# !pip install matplotlib==3.9.2
# !pip install transformers==4.38.2
# !pip install torch
# Out:
# Requirement already satisfied: pandas==2.2.3 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from pandas==2.2.3) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from pandas==2.2.3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from pandas==2.2.3) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.16.0)
# Collecting tensorflow==2.17.1
#   Using cached tensorflow-2.17.1-cp39-cp39-win_amd64.whl.metadata (3.3 kB)
# Collecting tensorflow-intel==2.17.1 (from tensorflow==2.17.1)
#   Using cached tensorflow_intel-2.17.1-cp39-cp39-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (24.12.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.4.0)
# Requirement already satisfied: packaging in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.17.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.69.0)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow-intel==2.17.1->tensorflow==2.17.1)
#   Using cached tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.2.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorflow-intel==2.17.1->tensorflow==2.17.1) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.44.0)
# Requirement already satisfied: rich in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (13.9.4)
# Requirement already satisfied: namex in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.0.8)
# Requirement already satisfied: optree in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.1.3)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (8.5.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (2.15.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.1->tensorflow==2.17.1) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.1->tensorflow==2.17.1) (0.1.2)
# Using cached tensorflow-2.17.1-cp39-cp39-win_amd64.whl (7.5 kB)
# Using cached tensorflow_intel-2.17.1-cp39-cp39-win_amd64.whl (382.2 MB)
# Downloading tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.5 MB 985.5 kB/s eta 0:00:06
#    ----- ---------------------------------- 0.8/5.5 MB 1.0 MB/s eta 0:00:05
#    ------- -------------------------------- 1.0/5.5 MB 1.1 MB/s eta 0:00:05
#    --------- ------------------------------ 1.3/5.5 MB 1.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.6/5.5 MB 1.1 MB/s eta 0:00:04
#    ------------- -------------------------- 1.8/5.5 MB 1.1 MB/s eta 0:00:04
#    --------------- ------------------------ 2.1/5.5 MB 1.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 2.4/5.5 MB 1.2 MB/s eta 0:00:03
#    ------------------- -------------------- 2.6/5.5 MB 1.2 MB/s eta 0:00:03
#    -------------------- ------------------- 2.9/5.5 MB 1.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.1/5.5 MB 1.2 MB/s eta 0:00:02
#    ------------------------ --------------- 3.4/5.5 MB 1.3 MB/s eta 0:00:02
#    -------------------------- ------------- 3.7/5.5 MB 1.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 3.9/5.5 MB 1.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 3.9/5.5 MB 1.2 MB/s eta 0:00:02
#    ------------------------------ --------- 4.2/5.5 MB 1.1 MB/s eta 0:00:02
#    -------------------------------- ------- 4.5/5.5 MB 1.1 MB/s eta 0:00:01
#    -------------------------------- ------- 4.5/5.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.7/5.5 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.7/5.5 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 1.0 MB/s eta 0:00:01
#    -------------------------------------- - 5.2/5.5 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 1.0 MB/s eta 0:00:00
# Installing collected packages: tensorboard, tensorflow-intel, tensorflow
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.16.2
#     Uninstalling tensorboard-2.16.2:
#       Successfully uninstalled tensorboard-2.16.2
#   Attempting uninstall: tensorflow-intel
#     Found existing installation: tensorflow-intel 2.16.2
#     Uninstalling tensorflow-intel-2.16.2:
#       Successfully uninstalled tensorflow-intel-2.16.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.16.2
#     Uninstalling tensorflow-2.16.2:
#       Successfully uninstalled tensorflow-2.16.2
# Successfully installed tensorboard-2.17.1 tensorflow-2.17.1 tensorflow-intel-2.17.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-cpu 2.16.2 requires tensorflow-intel==2.16.2; platform_system == "Windows", but you have tensorflow-intel 2.17.1 which is incompatible.
# Requirement already satisfied: pillow==11.1.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (11.1.0)
# Requirement already satisfied: matplotlib==3.9.2 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from matplotlib==3.9.2) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from matplotlib==3.9.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from matplotlib==3.9.2) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from matplotlib==3.9.2) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from matplotlib==3.9.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from matplotlib==3.9.2) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from matplotlib==3.9.2) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from matplotlib==3.9.2) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from matplotlib==3.9.2) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from matplotlib==3.9.2) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from importlib-resources>=3.2.0->matplotlib==3.9.2) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.9.2) (1.16.0)
# Requirement already satisfied: transformers==4.38.2 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (4.38.2)
# Requirement already satisfied: filelock in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from transformers==4.38.2) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from transformers==4.38.2) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from transformers==4.38.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from transformers==4.38.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from transformers==4.38.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from transformers==4.38.2) (2025.7.34)
# Requirement already satisfied: requests in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from transformers==4.38.2) (2.32.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from transformers==4.38.2) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from transformers==4.38.2) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from transformers==4.38.2) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (2025.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.38.2) (4.12.2)
# Requirement already satisfied: colorama in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from tqdm>=4.27->transformers==4.38.2) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from requests->transformers==4.38.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from requests->transformers==4.38.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from requests->transformers==4.38.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from requests->transformers==4.38.2) (2024.12.14)
# Requirement already satisfied: torch in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (2.7.1)
# Requirement already satisfied: filelock in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from torch) (2025.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sekai\.conda\envs\jupyter\lib\site-packages (from jinja2->torch) (3.0.2)

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
#
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %% [markdown]
# ### Importing Required Libraries

# %%
import zipfile
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten
from keras.applications import VGG16
from keras.optimizers import Adam
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing import image
import random

# %%
# Set seed for reproducibility
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# %% [markdown]
# ## <a id='toc1_'> </a> [Part 1 - Classification Problem: Classifying the defect on the aircraft as 'dent' or 'crack'](#toc1_)
#
# ### <a id='toc1_1_'></a> [1.1 Dataset Preparation](#toc1_)
#
# The first step is to load and prepare the dataset of aircraft images. These images are labeled either as 'dent' or 'crack'. We will also split the dataset into training, validation, and test sets.

# %%
#Set the batch size,epochs
batch_size = 32
n_epochs = 5
img_rows, img_cols = 224, 224
input_shape = (img_rows, img_cols, 3)

# %% [markdown]
# Extract the Dataset:
# Unzip the dataset to the current directory, creating directories for training, testing, and validation splits.

# %%
import tarfile
import urllib.request
import os
import shutil

# URL of the tar file
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/ZjXM4RKxlBK9__ZjHBLl5A/aircraft-damage-dataset-v1.tar"

# Define the path to save the file
tar_filename = "aircraft_damage_dataset_v1.tar"
extracted_folder = "aircraft_damage_dataset_v1"  # Folder where contents will be extracted

# Download the tar file
urllib.request.urlretrieve(url, tar_filename)
print(f"Downloaded {tar_filename}. Extraction will begin now.")

# Check if the folder already exists
if os.path.exists(extracted_folder):
    print(f"The folder '{extracted_folder}' already exists. Removing the existing folder.")
    
    # Remove the existing folder to avoid overwriting or duplication
    shutil.rmtree(extracted_folder)
    print(f"Removed the existing folder: {extracted_folder}")

# Extract the contents of the tar file
with tarfile.open(tar_filename, "r") as tar_ref:
    tar_ref.extractall()  # This will extract to the current directory
    print(f"Extracted {tar_filename} successfully.")
# Out:
# Downloaded aircraft_damage_dataset_v1.tar. Extraction will begin now.
# The folder 'aircraft_damage_dataset_v1' already exists. Removing the existing folder.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[10], line 22
#      19     print(f"The folder '{extracted_folder}' already exists. Removing the existing folder.")
#      21     # Remove the existing folder to avoid overwriting or duplication
# ---> 22     shutil.rmtree(extracted_folder)
#      23     print(f"Removed the existing folder: {extracted_folder}")
#      25 # Extract the contents of the tar file
#
# File c:\Users\sekai\.conda\envs\jupyter\lib\shutil.py:759, in rmtree(path, ignore_errors, onerror)
#     757     # can't continue even if onerror hook returns
#     758     return
# --> 759 return _rmtree_unsafe(path, onerror)
#
# File c:\Users\sekai\.conda\envs\jupyter\lib\shutil.py:624, in _rmtree_unsafe(path, onerror)
#     622         onerror(os.path.islink, fullname, sys.exc_info())
#     623         continue
# --> 624     _rmtree_unsafe(fullname, onerror)
#     625 else:
#     626     try:
#
# File c:\Users\sekai\.conda\envs\jupyter\lib\shutil.py:624, in _rmtree_unsafe(path, onerror)
#     622         onerror(os.path.islink, fullname, sys.exc_info())
#     623         continue
# --> 624     _rmtree_unsafe(fullname, onerror)
#     625 else:
#     626     try:
#
# File c:\Users\sekai\.conda\envs\jupyter\lib\shutil.py:633, in _rmtree_unsafe(path, onerror)
#     631     os.rmdir(path)
#     632 except OSError:
# --> 633     onerror(os.rmdir, path, sys.exc_info())
#
# File c:\Users\sekai\.conda\envs\jupyter\lib\shutil.py:631, in _rmtree_unsafe(path, onerror)
#     629             onerror(os.unlink, fullname, sys.exc_info())
#     630 try:
# --> 631     os.rmdir(path)
#     632 except OSError:
#     633     onerror(os.rmdir, path, sys.exc_info())
#
# PermissionError: [WinError 5] Access is denied: 'aircraft_damage_dataset_v1\\test\\crack'

# %% [markdown]
# The folder structure looks as follows:
#
# ```python
# aircraft_damage_dataset_v1/
# ├── train/
# │   ├── dent/
# │   └── crack/
# ├── valid/
# │   ├── dent/
# │   └── crack/
# └── test/
#     ├── dent/
#     └── crack/
#
# ```

# %%
# Define directories for train, test, and validation splits
extract_path = "aircraft_damage_dataset_v1"
train_dir = os.path.join(extract_path, 'train')
test_dir = os.path.join(extract_path, 'test')
valid_dir = os.path.join(extract_path, 'valid')

# %% [markdown]
# ## 1.2 Data Preprocessing
#
# Create data generators for training, validation, and testing datasets.
#
# First,we will create ImageDataGenerators used for training, validation and testing.
# The ImageDataGenerator class is part of Keras. It is a powerful utility for real-time image data augmentation, preprocessing, and feeding data into deep learning models during training. This class is particularly useful when working with image datasets that are too large to fit into memory all at once, or when you want to augment your dataset  to improve model generalization.
#
# We will create instances of the ImageDataGenerator class. Each instance corresponds to one of the datasets: training, validation, and testing.

# %%
# Create ImageDataGenerators to preprocess the data
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# Next, we use flow_from_directory() method to load the images from directory and generate the training dataset. The flow_from_directory() method is part of the ImageDataGenerator class in Keras, and it plays a crucial role in automating the process of loading, preprocessing, and batching images for training, validation, and testing.
# We use the train_datagen object to load and preprocess the training images. Specifically, the flow_from_directory() function is used to read images directly from the directory and generate batches of data that will be fed into the model for training.

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(img_rows, img_cols),   # Resize images to the size VGG16 expects
    batch_size=batch_size,
    seed = seed_value,
    class_mode='binary',
    shuffle=True # Binary classification: dent vs crack
)
# Out:
# Found 103 images belonging to 1 classes.

# %% [markdown]
# ## **Task 1: Create a `valid_generator` using the `valid_datagen` object**

# %%
valid_generator = valid_datagen.flow_from_directory(
    directory=valid_dir,
    class_mode = 'binary',
    seed = seed_value,
    batch_size = batch_size,
    shuffle=False,
    target_size=(img_rows, img_cols)
)
# Out:
# Found 96 images belonging to 2 classes.

# %% [markdown]
# ## **Task 2: Create a `test_generator` using the `test_datagen` object**

# %%
#Write your code here
test_generator = test_datagen.flow_from_directory(
    directory = test_dir,
    class_mode = 'binary',
    seed = seed_value,
    batch_size = batch_size,
    shuffle = False,
    target_size = (img_rows, img_cols)
)
# Out:
# Found 50 images belonging to 2 classes.

# %% [markdown]
# ## 1.3 Model Definition
#
# Here, we define the model architecture by using a pre-trained VGG16 model as the base, adding custom layers on top for binary classification of 'dent' and 'crack' types of damage.

# %% [markdown]
# ## **Task 3: Load the pre-trained model VGG16**

# %%
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_rows, img_cols, 3))

# %% [markdown]
# Now, we modify the VGG16 model for our specific classification task. We extract the output from the last layer of the pre-trained VGG16 model, and then create a new model with this modified output. Then we will freeze the base VGG16 model layers so that their weights will not be updated during training.

# %%
output = base_model.layers[-1].output
output = keras.layers.Flatten()(output)
base_model = Model(base_model.input, output)

# Freeze the base VGG16 model layers
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# After using VGG16 as a feature extractor, we add our own classifier on top of the VGG16 model. This involves adding fully connected layers (Dense), activation functions (like ReLU), and sometimes Dropout layers to avoid overfitting.
# Here, we are adding two dense layers with 512 units each, followed by a Dropout layer, and finally, a Dense layer with one unit and a sigmoid activation to output the probability for binary classification ("dent" vs "crack").

# %%
# Build the custom model
model = Sequential()
model.add(base_model)
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ## **Task 4: Compile the model**

# %%
# Write your code here
model.compile(
    optimizer = Adam(learning_rate=0.0001),
    loss = 'binary_crossentropy',
    metrics = ['accuracy']
)

# %% [markdown]
# ## 1.4 Model Training
#
# - This section covers the process of training the model using the prepared dataset.

# %% [markdown]
# ## Task 5: Model Training

# %%
history = model.fit(
    train_generator,
    epochs = n_epochs,
    validation_data = valid_generator
)
# Out:
# Epoch 1/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 8.6151e-07 - val_accuracy: 0.5000 - val_loss: 8.8795
# Epoch 2/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 5.0912e-07 - val_accuracy: 0.5000 - val_loss: 9.4421
# Epoch 3/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 1.0027e-06 - val_accuracy: 0.5000 - val_loss: 9.8362
# Epoch 4/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 2.6096e-07 - val_accuracy: 0.5000 - val_loss: 10.1116
# Epoch 5/5
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 4s/step - accuracy: 1.0000 - loss: 2.5721e-08 - val_accuracy: 0.5000 - val_loss: 10.3032

# %%
# Access the training history
train_history = model.history.history  # After training

# %% [markdown]
# ## 1.5 Visualizing Training Results
#
# - After training the model, we visualize the training and validation accuracy and loss to understand the model's learning process.

# %% [markdown]
# ### Plot loss curves for training and validation sets

# %%
# Plot the loss for both training and validation
plt.title("Training Loss")
plt.ylabel("Loss")
plt.xlabel('Epoch')
plt.plot(train_history['loss'])
plt.show()

plt.title("Validation Loss")
plt.ylabel("Loss")
plt.xlabel('Epoch')
plt.plot(train_history['val_loss'])
plt.show()

# %% [markdown]
# ## Task 6: Plot accuracy curves for training and validation sets

# %%
# Write your code here
plt.title("Accuracy Curve")
plt.ylabel("Accuracy")
plt.xlabel('Epoch')
plt.plot(train_history['val_accuracy'], label="Validation Accuracy")
plt.show()

plt.title("Accuracy Curve")
plt.ylabel("Accuracy")
plt.xlabel('Epoch')
plt.plot(train_history['accuracy'], label="Training Accuracy")
plt.show()

# %% [markdown]
# ## 1.6 Model Evaluation
#
# Now we evaluate the trained model on the test dataset. Calculates test loss and accuracy by evaluating the test generator. Predictions are made for the test dataset, and the results are compared to true labels.

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(test_generator, steps=test_generator.samples // test_generator.batch_size)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.7812 - loss: 4.0527
# Test Loss: 4.0527
# Test Accuracy: 0.7812

# %% [markdown]
#  ## 1.7 Visualizing Predictions
#
# Display test images alongside their true and predicted labels.
#
# True labels and predictions are retrieved.
# Images are displayed with labels for visual inspection of model performance.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image

# Function to plot a single image and its prediction
def plot_image_with_title(image, model, true_label, predicted_label, class_names):
    plt.figure(figsize=(6, 6))
    plt.imshow(image)

    # Convert labels from one-hot to class indices if needed, but for binary labels it's just 0 or 1
    true_label_name = class_names[true_label]  # Labels are already in class indices
    pred_label_name = class_names[predicted_label]  # Predictions are 0 or 1

    plt.title(f"True: {true_label_name}\nPred: {pred_label_name}")
    plt.axis('off')
    plt.show()

# Function to test the model with images from the test set
def test_model_on_image(test_generator, model, index_to_plot=0):
    # Get a batch of images and labels from the test generator
    test_images, test_labels = next(test_generator)

    # Make predictions on the batch
    predictions = model.predict(test_images)

    # In binary classification, predictions are probabilities (float). Convert to binary (0 or 1)
    predicted_classes = (predictions > 0.5).astype(int).flatten()

    # Get the class indices from the test generator and invert them to get class names
    class_indices = test_generator.class_indices
    class_names = {v: k for k, v in class_indices.items()}  # Invert the dictionary

    # Specify the image to display based on the index
    image_to_plot = test_images[index_to_plot]
    true_label = test_labels[index_to_plot]
    predicted_label = predicted_classes[index_to_plot]

    # Plot the selected image with its true and predicted labels
    plot_image_with_title(image=image_to_plot, model=model, true_label=true_label, predicted_label=predicted_label, class_names=class_names)

# %% [markdown]
# ## **Task 7: Visualizing the results**

# %%
#Write your code here

test_model_on_image(test_generator, model, index_to_plot=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
